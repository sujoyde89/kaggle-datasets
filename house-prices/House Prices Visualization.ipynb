# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
df_original = train.append(test, ignore_index = True)

# %%
fig, (axis1,axis2) = plt.subplots(1,2,figsize=(15,5))
sns.boxplot(x = 'MSSubClass', y ='SalePrice', data=train, ax=axis1)
sns.boxplot(x = 'MSZoning', y ='SalePrice', data=train, ax=axis2)

# %%
train['MSZoning'].value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
fig, (axis1,axis2) = plt.subplots(1,2,figsize=(15,5))
sns.boxplot(x = 'Street', y ='SalePrice', data=train, ax=axis1)
sns.boxplot(x = 'LotShape', y ='SalePrice', data=train, ax=axis2)

# %%
train['LotShape'].value_counts()
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64

# %%
fig, (axis1,axis2,axis3,axis4) = plt.subplots(1,4,figsize=(15,5))
sns.boxplot(x = 'LandContour', y ='SalePrice', data=train, ax=axis1)
sns.boxplot(x = 'Utilities', y ='SalePrice', data=train, ax=axis2)
sns.boxplot(x = 'LotConfig', y ='SalePrice', data=train, ax=axis3)
sns.boxplot(x = 'LandSlope', y ='SalePrice', data=train, ax=axis4)

# %%
train['LandContour'].value_counts()
# Out:
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: LandContour, dtype: int64

# %%
train['LotConfig'].value_counts()
# Out:
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64

# %%
train['LandSlope'].value_counts()
# Out:
# Gtl    1382
# Mod      65
# Sev      13
# Name: LandSlope, dtype: int64

# %%
train['Condition1'].value_counts()
# Out:
# Norm      1260
# Feedr       81
# Artery      48
# RRAn        26
# PosN        19
# RRAe        11
# PosA         8
# RRNn         5
# RRNe         2
# Name: Condition1, dtype: int64

# %%
train['Condition2'].value_counts()
# Out:
# Norm      1445
# Feedr        6
# PosN         2
# RRNn         2
# Artery       2
# PosA         1
# RRAn         1
# RRAe         1
# Name: Condition2, dtype: int64

# %%
sns.boxplot(x = 'Neighborhood', y ='SalePrice', data=train)

# %%
fig, (axis1,axis2) = plt.subplots(1,2,figsize=(15,5))
sns.boxplot(x = 'Condition1', y ='SalePrice', data=train, ax=axis1)
sns.boxplot(x = 'Condition2', y ='SalePrice', data=train, ax=axis2)

# %%
train['BldgType'].value_counts()
# Out:
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64

# %%
train['HouseStyle'].value_counts()
# Out:
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: HouseStyle, dtype: int64

# %%
fig, (axis1,axis2) = plt.subplots(1,2,figsize=(15,5))
sns.boxplot(x = 'BldgType', y ='SalePrice', data=train, ax=axis1)
sns.boxplot(x = 'HouseStyle', y ='SalePrice', data=train, ax=axis2)

# %%
train['OverallQual'].value_counts()
# Out:
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64

# %%
train['OverallCond'].value_counts()
# Out:
# 5    821
# 6    252
# 7    205
# 8     72
# 4     57
# 3     25
# 9     22
# 2      5
# 1      1
# Name: OverallCond, dtype: int64

# %%
fig, (axis1,axis2) = plt.subplots(1,2,figsize=(15,5))
sns.boxplot(x = 'OverallQual', y ='SalePrice', data=train, ax=axis1)
sns.boxplot(x = 'OverallCond', y ='SalePrice', data=train, ax=axis2)

# %%
train['RoofStyle'].value_counts()
# Out:
# Gable      1141
# Hip         286
# Flat         13
# Gambrel      11
# Mansard       7
# Shed          2
# Name: RoofStyle, dtype: int64

# %%
train['RoofMatl'].value_counts()
# Out:
# CompShg    1434
# Tar&Grv      11
# WdShngl       6
# WdShake       5
# Membran       1
# Metal         1
# Roll          1
# ClyTile       1
# Name: RoofMatl, dtype: int64

# %%
fig, (axis1,axis2) = plt.subplots(1,2,figsize=(15,5))
sns.boxplot(x = 'RoofStyle', y ='SalePrice', data=train, ax=axis1)
sns.boxplot(x = 'RoofMatl', y ='SalePrice', data=train, ax=axis2)

# %%
train['Exterior1st'].value_counts()
# Out:
# VinylSd    515
# HdBoard    222
# MetalSd    220
# Wd Sdng    206
# Plywood    108
# CemntBd     61
# BrkFace     50
# WdShing     26
# Stucco      25
# AsbShng     20
# BrkComm      2
# Stone        2
# AsphShn      1
# ImStucc      1
# CBlock       1
# Name: Exterior1st, dtype: int64

# %%
plt.rcParams['figure.figsize']=(20,10)
sns.boxplot(x = 'Exterior1st', y ='SalePrice', data=train)

# %%
train['Exterior2nd'].value_counts()
# Out:
# VinylSd    504
# MetalSd    214
# HdBoard    207
# Wd Sdng    197
# Plywood    142
# CmentBd     60
# Wd Shng     38
# Stucco      26
# BrkFace     25
# AsbShng     20
# ImStucc     10
# Brk Cmn      7
# Stone        5
# AsphShn      3
# CBlock       1
# Other        1
# Name: Exterior2nd, dtype: int64

# %%
plt.rcParams['figure.figsize']=(20,10)
sns.boxplot(x = 'Exterior2nd', y ='SalePrice', data=train)

# %%
train['MasVnrType'].value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
sns.boxplot(x = 'MasVnrType', y ='SalePrice', data=train)

# %%
train['ExterQual'].value_counts()
# Out:
# TA    906
# Gd    488
# Ex     52
# Fa     14
# Name: ExterQual, dtype: int64

# %%
train['ExterCond'].value_counts()
# Out:
# TA    1282
# Gd     146
# Fa      28
# Ex       3
# Po       1
# Name: ExterCond, dtype: int64

# %%
fig, (axis1,axis2) = plt.subplots(1,2,figsize=(15,5))
sns.boxplot(x = 'ExterQual', y ='SalePrice', data=train, ax=axis1)
sns.boxplot(x = 'ExterCond', y ='SalePrice', data=train, ax=axis2)

# %%
train['Foundation'].value_counts()
# Out:
# PConc     647
# CBlock    634
# BrkTil    146
# Slab       24
# Stone       6
# Wood        3
# Name: Foundation, dtype: int64

# %%
train['BsmtQual'].value_counts()
# Out:
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64

# %%
train['BsmtCond'].value_counts()
# Out:
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: BsmtCond, dtype: int64

# %%
fig, (axis1,axis2,axis3) = plt.subplots(1,3,figsize=(15,5))
sns.boxplot(x = 'Foundation', y ='SalePrice', data=train, ax=axis1)
sns.boxplot(x = 'BsmtQual', y ='SalePrice', data=train, ax=axis2)
sns.boxplot(x = 'BsmtCond', y ='SalePrice', data=train, ax=axis3)

# %%
train['BsmtExposure'].value_counts()
# Out:
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64

# %%
train['BsmtFinType1'].value_counts()
# Out:
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64

# %%
train['BsmtFinType2'].value_counts()
# Out:
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64

# %%
fig, (axis1,axis2,axis3) = plt.subplots(1,3,figsize=(15,5))
sns.boxplot(x = 'BsmtExposure', y ='SalePrice', data=train, ax=axis1)
sns.boxplot(x = 'BsmtFinType1', y ='SalePrice', data=train, ax=axis2)
sns.boxplot(x = 'BsmtFinType2', y ='SalePrice', data=train, ax=axis3)

# %%
train['Heating'].value_counts()
# Out:
# GasA     1428
# GasW       18
# Grav        7
# Wall        4
# OthW        2
# Floor       1
# Name: Heating, dtype: int64

# %%
train['HeatingQC'].value_counts()
# Out:
# Ex    741
# TA    428
# Gd    241
# Fa     49
# Po      1
# Name: HeatingQC, dtype: int64

# %%
train['CentralAir'].value_counts()
# Out:
# Y    1365
# N      95
# Name: CentralAir, dtype: int64

# %%
train['Electrical'].value_counts()
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
fig, (axis1,axis2,axis3,axis4) = plt.subplots(1,4,figsize=(15,5))
sns.boxplot(x = 'Heating', y ='SalePrice', data=train, ax=axis1)
sns.boxplot(x = 'HeatingQC', y ='SalePrice', data=train, ax=axis2)
sns.boxplot(x = 'CentralAir', y ='SalePrice', data=train, ax=axis3)
sns.boxplot(x = 'Electrical', y ='SalePrice', data=train, ax=axis4)

# %%
train['BsmtFullBath'].value_counts()
# Out:
# 0    856
# 1    588
# 2     15
# 3      1
# Name: BsmtFullBath, dtype: int64

# %%
train['BsmtHalfBath'].value_counts()
# Out:
# 0    1378
# 1      80
# 2       2
# Name: BsmtHalfBath, dtype: int64

# %%
train['FullBath'].value_counts()
# Out:
# 2    768
# 1    650
# 3     33
# 0      9
# Name: FullBath, dtype: int64

# %%
train['HalfBath'].value_counts()
# Out:
# 0    913
# 1    535
# 2     12
# Name: HalfBath, dtype: int64

# %%
fig, (axis1,axis2,axis3,axis4) = plt.subplots(1,4,figsize=(15,5))
sns.boxplot(x = 'BsmtFullBath', y ='SalePrice', data=train, ax=axis1)
sns.boxplot(x = 'BsmtHalfBath', y ='SalePrice', data=train, ax=axis2)
sns.boxplot(x = 'FullBath', y ='SalePrice', data=train, ax=axis3)
sns.boxplot(x = 'HalfBath', y ='SalePrice', data=train, ax=axis4)

# %%
train['BedroomAbvGr'].value_counts()
# Out:
# 3    804
# 2    358
# 4    213
# 1     50
# 5     21
# 6      7
# 0      6
# 8      1
# Name: BedroomAbvGr, dtype: int64

# %%
train['KitchenAbvGr'].value_counts()
# Out:
# 1    1392
# 2      65
# 3       2
# 0       1
# Name: KitchenAbvGr, dtype: int64

# %%
train['KitchenQual'].value_counts()
# Out:
# TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: KitchenQual, dtype: int64

# %%
train['TotRmsAbvGrd'].value_counts()
# Out:
# 6     402
# 7     329
# 5     275
# 8     187
# 4      97
# 9      75
# 10     47
# 11     18
# 3      17
# 12     11
# 14      1
# 2       1
# Name: TotRmsAbvGrd, dtype: int64

# %%
fig, (axis1,axis2,axis3,axis4) = plt.subplots(1,4,figsize=(15,5))
sns.boxplot(x = 'BedroomAbvGr', y ='SalePrice', data=train, ax=axis1)
sns.boxplot(x = 'KitchenAbvGr', y ='SalePrice', data=train, ax=axis2)
sns.boxplot(x = 'KitchenQual', y ='SalePrice', data=train, ax=axis3)
sns.boxplot(x = 'TotRmsAbvGrd', y ='SalePrice', data=train, ax=axis4)

# %%
train['Functional'].value_counts()
# Out:
# Typ     1360
# Min2      34
# Min1      31
# Mod       15
# Maj1      14
# Maj2       5
# Sev        1
# Name: Functional, dtype: int64

# %%
train['Fireplaces'].value_counts()
# Out:
# 0    690
# 1    650
# 2    115
# 3      5
# Name: Fireplaces, dtype: int64

# %%
train['GarageType'].value_counts()
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
train['GarageFinish'].value_counts()
# Out:
# Unf    605
# RFn    422
# Fin    352
# Name: GarageFinish, dtype: int64

# %%
fig, (axis1,axis2,axis3,axis4) = plt.subplots(1,4,figsize=(15,5))
sns.boxplot(x = 'Functional', y ='SalePrice', data=train, ax=axis1)
sns.boxplot(x = 'Fireplaces', y ='SalePrice', data=train, ax=axis2)
sns.boxplot(x = 'GarageType', y ='SalePrice', data=train, ax=axis3)
sns.boxplot(x = 'GarageFinish', y ='SalePrice', data=train, ax=axis4)

# %%
train['GarageCars'].value_counts()
# Out:
# 2    824
# 1    369
# 3    181
# 0     81
# 4      5
# Name: GarageCars, dtype: int64

# %%
train['GarageQual'].value_counts()
# Out:
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: GarageQual, dtype: int64

# %%
train['GarageCond'].value_counts()
# Out:
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: GarageCond, dtype: int64

# %%
train['PavedDrive'].value_counts()
# Out:
# Y    1340
# N      90
# P      30
# Name: PavedDrive, dtype: int64

# %%
fig, (axis1,axis2,axis3,axis4) = plt.subplots(1,4,figsize=(15,5))
sns.boxplot(x = 'GarageCars', y ='SalePrice', data=train, ax=axis1)
sns.boxplot(x = 'GarageQual', y ='SalePrice', data=train, ax=axis2)
sns.boxplot(x = 'GarageCond', y ='SalePrice', data=train, ax=axis3)
sns.boxplot(x = 'PavedDrive', y ='SalePrice', data=train, ax=axis4)

# %%
train['YrSold'].value_counts()
# Out:
# 2009    338
# 2007    329
# 2006    314
# 2008    304
# 2010    175
# Name: YrSold, dtype: int64

# %%
sns.boxplot(x = 'YrSold', y ='SalePrice', data=train)

# %%
train['SaleType'].value_counts()
# Out:
# WD       1267
# New       122
# COD        43
# ConLD       9
# ConLI       5
# ConLw       5
# CWD         4
# Oth         3
# Con         2
# Name: SaleType, dtype: int64

# %%
train['SaleCondition'].value_counts()
# Out:
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64

# %%
fig, (axis1,axis2) = plt.subplots(1,2,figsize=(20,5))
sns.boxplot(x = 'SaleType', y ='SalePrice', data=train, ax=axis1)
sns.boxplot(x = 'SaleCondition', y ='SalePrice', data=train, ax=axis2)

# %%
sns.boxplot(x = 'MoSold', y ='SalePrice', data=train)

# %%
train['TotalBsmtFin'] = train['BsmtFinSF1'] + train['BsmtFinSF2']
train['Age'] = train['YrSold'] - train['YearBuilt']
train['Remodel_Age'] = train['YrSold'] - train['YearRemodAdd']
train['Garage_Age'] = train['YrSold'] - train['GarageYrBlt']
train['Porch_Area'] = train['OpenPorchSF'] + train['ScreenPorch'] + train['3SsnPorch'] + train['EnclosedPorch']

test['TotalBsmtFin'] = test['BsmtFinSF1'] + test['BsmtFinSF2']
test['Age'] = test['YrSold'] - test['YearBuilt']
test['Remodel_Age'] = test['YrSold'] - test['YearRemodAdd']
test['Garage_Age'] = test['YrSold'] - test['GarageYrBlt']
test['Porch_Area'] = test['OpenPorchSF'] + test['ScreenPorch'] + test['3SsnPorch'] + test['EnclosedPorch']

# %%
cont = ['LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','TotalBsmtSF','1stFlrSF','2ndFlrSF','LowQualFinSF',
        'GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch',
        'PoolArea','MiscVal','TotalBsmtFin','Age','Remodel_Age','Garage_Age','Porch_Area','SalePrice']
train_cont = train[cont]
corr = train_cont.corr()
corr.sort_values(["SalePrice"], ascending = False, inplace = True)
print(corr.SalePrice)
# Out:
# SalePrice        1.000000
# GrLivArea        0.708624
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# MasVnrArea       0.477493
# BsmtFinSF1       0.386420
# TotalBsmtFin     0.366328
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# LotArea          0.263843
# Porch_Area       0.195739
# ScreenPorch      0.111447
# PoolArea         0.092404
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# MiscVal         -0.021190
# LowQualFinSF    -0.025606
# EnclosedPorch   -0.128578
# Garage_Age      -0.487069
# Remodel_Age     -0.509079
# Age             -0.523350
# Name: SalePrice, dtype: float64

# %%
train['GrLivArea'].describe()
# Out:
# count    1460.000000
# mean     1515.463699
# std       525.480383
# min       334.000000
# 25%      1129.500000
# 50%      1464.000000
# 75%      1776.750000
# max      5642.000000
# Name: GrLivArea, dtype: float64

# %%
test['GrLivArea'].describe()
# Out:
# count    1459.000000
# mean     1486.045922
# std       485.566099
# min       407.000000
# 25%      1117.500000
# 50%      1432.000000
# 75%      1721.000000
# max      5095.000000
# Name: GrLivArea, dtype: float64

# %%
sns.lmplot(x = 'GrLivArea', y ='SalePrice', data=train)

# %%
train['TotalBsmtSF'].describe()
# Out:
# count    1460.000000
# mean     1057.429452
# std       438.705324
# min         0.000000
# 25%       795.750000
# 50%       991.500000
# 75%      1298.250000
# max      6110.000000
# Name: TotalBsmtSF, dtype: float64

# %%
test['TotalBsmtSF'].describe()
# Out:
# count    1458.000000
# mean     1046.117970
# std       442.898624
# min         0.000000
# 25%       784.000000
# 50%       988.000000
# 75%      1305.000000
# max      5095.000000
# Name: TotalBsmtSF, dtype: float64

# %%
sns.lmplot(x = 'TotalBsmtSF', y ='SalePrice', data=train)

# %%
sns.lmplot(x = 'LotArea', y ='SalePrice', data=train)

# %%
sns.lmplot(x = 'MasVnrArea', y ='SalePrice', data=train)

# %%
sns.distplot(train.SalePrice)
